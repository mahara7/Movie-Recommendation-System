# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.6.0-cp310-cp310-win_amd64.whl (7.2 MB)
#      ---------------------------------------- 7.2/7.2 MB 2.2 MB/s eta 0:00:00
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.2.0-cp310-cp310-win_amd64.whl (3.3 MB)
#      ---------------------------------------- 3.3/3.3 MB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.23.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.37.3-py3-none-any.whl (959 kB)
#      -------------------------------------- 960.0/960.0 kB 4.1 MB/s eta 0:00:00
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-win_amd64.whl (55 kB)
#      ---------------------------------------- 55.3/55.3 kB 3.0 MB/s eta 0:00:00
# Collecting contourpy>=1.0.1
#   Downloading contourpy-1.0.5-cp310-cp310-win_amd64.whl (164 kB)
#      -------------------------------------- 164.1/164.1 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: six>=1.5 in c:\users\prati\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.0.5 cycler-0.11.0 fonttools-4.37.3 kiwisolver-1.4.4 matplotlib-3.6.0 pillow-9.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_csv('main_data.csv')
df.head()
# Out:
#        director_name     actor_1_name      actor_2_name          actor_3_name  \
# 0      James Cameron      CCH Pounder  Joel David Moore             Wes Studi
# 1     Gore Verbinski      Johnny Depp     Orlando Bloom        Jack Davenport
# 2         Sam Mendes  Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3  Christopher Nolan        Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4        Doug Walker      Doug Walker        Rob Walker               unknown
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# 1         Action Adventure Fantasy
# 2        Action Adventure Thriller
# 3                  Action Thriller
# 4                      Documentary
#
#                                          movie_title  \
# 0                                             avatar
# 1           pirates of the caribbean: at world's end
# 2                                            spectre
# 3                              the dark knight rises
# 4  star wars: episode vii - the force awakens    ...
#
#                                                 comb
# 0  CCH Pounder Joel David Moore Wes Studi James C...
# 1  Johnny Depp Orlando Bloom Jack Davenport Gore ...
# 2  Christoph Waltz Rory Kinnear Stephanie Sigman ...
# 3  Tom Hardy Christian Bale Joseph Gordon-Levitt ...
# 4  Doug Walker Rob Walker unknown Doug Walker Doc...

# %%
X = df.iloc[:]
y = df.iloc[:]

# %%
X_train, X_test, y_train, y_test =train_test_split(X, y, test_size=0.20, random_state=42)
X_train.head()
# Out:
#         director_name      actor_1_name       actor_2_name  \
# 776     Marc Lawrence     Michael Kelly           Kim Shaw
# 5780  Andy Muschietti      James McAvoy   Jessica Chastain
# 183    Chris Columbus  Daniel Radcliffe         Fiona Shaw
# 2197       Kirk Jones    Robert De Niro        James Frain
# 4173        Bill Muir     Alex Kendrick  Jansen Panettiere
#
#             actor_3_name                    genres  \
# 776          Kevin Brown      Comedy Drama Romance
# 5780          Bill Hader            Horror Fantasy
# 183         Verne Troyer  Adventure Family Fantasy
# 2197  Brendan Sexton III           Adventure Drama
# 4173         Tiya Sircar  Adventure Family Fantasy
#
#                                             movie_title  \
# 776                     did you hear about the morgans?
# 5780                                     it chapter two
# 183               harry potter and the sorcerer's stone
# 2197                                   everybody's fine
# 4173  the lost medallion: the adventures of billy stone
#
#                                                    comb
# 776   Michael Kelly Kim Shaw Kevin Brown Marc Lawren...
# 5780  James McAvoy Jessica Chastain Bill Hader Andy ...
# 183   Daniel Radcliffe Fiona Shaw Verne Troyer Chris...
# 2197  Robert De Niro James Frain Brendan Sexton III ...
# 4173  Alex Kendrick Jansen Panettiere Tiya Sircar Bi...

# %%
def create_similarity():
    data = pd.read_csv('main_data.csv')
    cv = CountVectorizer()
    count_matrix = cv.fit_transform(data['comb'])
    similarity = cosine_similarity(count_matrix)
    return data,similarity
    print(similarty)

# %%
def rcmd(m):
    m = m.lower()
    try:
        df.head()
        similarity.shape
    except:
        data, similarity = create_similarity()
    if m not in data['movie_title'].unique():
        return('Sorry! The movie you requested is not in our database. Please check the spelling or try with some other movies')
    else:
        i = df.loc[data['movie_title']==m].index[0]
        lst = list(enumerate(similarity[i]))
        lst = sorted(lst, key = lambda x:x[1] ,reverse=True)
        lst = lst[1:11] # excluding first item since it is the requested movie itself
        l = []
        for i in range(len(lst)):
            a = lst[i][0]
            l.append(data['movie_title'][a])
        return l
